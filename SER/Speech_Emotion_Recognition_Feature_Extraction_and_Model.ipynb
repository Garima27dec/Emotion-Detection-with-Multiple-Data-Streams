# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### General imports ###
import os
from glob import glob
import pickle
import itertools
import numpy as np
from scipy.stats import zscore
from sklearn.model_selection import train_test_split

### Graph imports ###
import matplotlib.pyplot as plt
from PIL import Image

### Audio import ###
import librosa
import IPython
from IPython.display import Audio, Image

# %%
import tensorflow
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, TimeDistributed, concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, LeakyReLU, Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from keras.utils import np_utils
from keras.utils import plot_model
from sklearn.preprocessing import LabelEncoder

### Warning ###
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = '/content/drive/MyDrive/Emotion_Recognition/SER/RAVDESS/'
file_names = os.listdir(file_path)

# %%
# RAVDESS Database
label_dict_ravdess = {'02': 'Neutral', '03':'Happy', '04':'Sad', '05':'Anger', '06':'Fear', '07':'Disgust', '08':'Surprise'}

# Set audio files labels
def set_label_ravdess(audio_file, gender_differentiation):
    label = label_dict_ravdess.get(audio_file[6:-16])
    if gender_differentiation == True:
        if int(audio_file[18:-4])%2 == 0: # Female
            label = 'f_' + label
        if int(audio_file[18:-4])%2 == 1: # Male
            label = 'm_' + label
    return label

# %%
# Start feature extraction
print("Import Data: START")

# Audio file path and names
file_path = '/content/drive/MyDrive/Emotion_Recognition/SER/RAVDESS/'
file_names = os.listdir(file_path)

# Initialize features and labels list
signal = []
labels = []

# Sample rate (16.0 kHz)
sample_rate = 16000

# Max pad lenght (3.0 sec)
max_pad_len = 49100

# Compute spectogram for all audio file
for audio_index, audio_file in enumerate(file_names):

    if audio_file[6:-16] in list(label_dict_ravdess.keys()):

        # Read audio file
        y, sr = librosa.core.load(file_path + audio_file, sr=sample_rate, offset=0.5)

        # Z-normalization
        y = zscore(y)

        # Padding or truncated signal
        if len(y) < max_pad_len:
            y_padded = np.zeros(max_pad_len)
            y_padded[:len(y)] = y
            y = y_padded
        elif len(y) > max_pad_len:
            y = np.asarray(y[:max_pad_len])

        # Add to signal list
        signal.append(y)

        # Set label
        labels.append(set_label_ravdess(audio_file, False))

        # Print running...
        if (audio_index % 100 == 0):
            print("Import Data: RUNNING ... {} files".format(audio_index))

# Cast labels to array
labels = np.asarray(labels).ravel()

# Stop feature extraction
print("Import Data: END \n")
print("Number of audio files imported: {}".format(labels.shape[0]))
# Out:
# Import Data: START
# Import Data: RUNNING ... 0 files
# Import Data: RUNNING ... 100 files
# Import Data: RUNNING ... 200 files
# Import Data: RUNNING ... 300 files
# Import Data: RUNNING ... 400 files
# Import Data: RUNNING ... 500 files
# Import Data: RUNNING ... 600 files
# Import Data: RUNNING ... 700 files
# Import Data: RUNNING ... 800 files
# Import Data: RUNNING ... 900 files
# Import Data: RUNNING ... 1000 files
# Import Data: RUNNING ... 1100 files
# Import Data: RUNNING ... 1200 files
# Import Data: RUNNING ... 1300 files
# Import Data: RUNNING ... 1400 files
# Import Data: END
#
# Number of audio files imported: 1344

# %%
# Select one random audio file
random_idx = np.random.randint(len(labels))
random_label = labels[random_idx]
random_signal = signal[random_idx]
random_filename = file_names[random_idx]

# Plot signal wave
plt.figure(figsize=(10,5))
plt.plot(np.arange(len(random_signal))/float(sample_rate), random_signal)
plt.xlim((np.arange(len(random_signal))/float(sample_rate))[0], (np.arange(len(random_signal))/float(sample_rate))[-1])
plt.xlabel('Time (s)', fontsize=16)
plt.ylabel('Amplitude (dB)', fontsize=16)
plt.title("Signal wave of file '{}' with label {}".format(random_filename, random_label), fontsize=18)
plt.show()

# Play audio file
print("Audio file '{}':".format(random_filename))
Audio(random_signal, rate=sample_rate)
# Out:
# Audio file '03-01-04-02-02-02-17.wav':
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Number of augmented data
nb_augmented = 2

# Function to add noise to a signals with a desired Signal Noise ratio (SNR)
def noisy_signal(signal, snr_low=15, snr_high=30, nb_augmented=2):

    # Signal length
    signal_len = len(signal)

    # Generate White noise
    noise = np.random.normal(size=(nb_augmented, signal_len))

    # Compute signal and noise power
    s_power = np.sum((signal / (2.0 ** 15)) ** 2) / signal_len
    n_power = np.sum((noise / (2.0 ** 15)) ** 2, axis=1) / signal_len

    # Random SNR: Uniform [15, 30]
    snr = np.random.randint(snr_low, snr_high)

    # Compute K coeff for each noise
    K = np.sqrt((s_power / n_power) * 10 ** (- snr / 10))
    K = np.ones((signal_len, nb_augmented)) * K

    # Generate noisy signal
    return signal + K.T * noise

# %%
# Generate noisy signals from signal list
print("Data Augmentation: START")
augmented_signal = list(map(noisy_signal, signal))
print("Data Augmentation: END!")
# Out:
# Data Augmentation: START
# Data Augmentation: END!

# %%
# Plot signal wave
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(np.arange(len(random_signal))/float(sample_rate), random_signal)
plt.xlim((np.arange(len(random_signal))/float(sample_rate))[0], (np.arange(len(random_signal))/float(sample_rate))[-1])
plt.xlabel('Time (s)', fontsize=16)
plt.ylabel('Amplitude (dB)', fontsize=16)
plt.title("Signal wave of file '{}' ".format(random_filename), fontsize=18)

# Plot signal wave with noise
plt.subplot(1,2,2)
plt.plot(np.arange(len(random_signal))/float(sample_rate), augmented_signal[random_idx][0])
plt.xlim((np.arange(len(random_signal))/float(sample_rate))[0], (np.arange(len(random_signal))/float(sample_rate))[-1])
plt.xlabel('Time (s)', fontsize=16)
plt.ylabel('Amplitude (dB)', fontsize=16)
plt.title("Signal wave of file '{}' with Noise".format(random_filename), fontsize=18)
plt.show()

# Play audio file
print("Audio file '{}':".format(random_filename))
IPython.display.display(Audio(random_signal, rate=sample_rate))

# Play same audio file with noise
print("Audio file '{}' with noise:".format(random_filename))
IPython.display.display(Audio(augmented_signal[random_idx][0], rate=sample_rate))
# Out:
# Audio file '03-01-04-02-02-02-17.wav':
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio file '03-01-04-02-02-02-17.wav' with noise:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def mel_spectrogram(y, sr=16000, n_fft=512, win_length=256, hop_length=128, window='hamming', n_mels=128, fmax=4000):

    # Compute spectogram
    mel_spect = np.abs(librosa.stft(y, n_fft=n_fft, window=window, win_length=win_length, hop_length=hop_length)) ** 2

    # Compute mel spectrogram
    mel_spect = librosa.feature.melspectrogram(S=mel_spect, sr=sr, n_mels=n_mels, fmax=fmax)

    # Compute log-mel spectrogram
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)

    return mel_spect

# %%
# Start feature extraction
print("Feature extraction: START")

# Compute spectogram for all audio file
mel_spect = np.asarray(list(map(mel_spectrogram, signal)))
augmented_mel_spect = [np.asarray(list(map(mel_spectrogram, augmented_signal[i]))) for i in range(len(augmented_signal))]

# Stop feature extraction
print("Feature extraction: END!")
# Out:
# Feature extraction: START
# Feature extraction: END!

# %%
# Plot one random Spectogram
plt.figure(figsize=(10, 5))
plt.imshow(mel_spect[np.random.randint(len(mel_spect))], origin='lower', aspect='auto', cmap='viridis')
plt.title('Log-Mel Spectrogram of an audio file', fontsize=26)
plt.tight_layout()
plt.show()

# %%
print(mel_spect.shape)
# Out:
# (1344, 128, 384)

# %%
# Build Train and test dataset
MEL_SPECT_train, MEL_SPECT_test, AUG_MEL_SPECT_train, AUG_MEL_SPECT_test, label_train, label_test = train_test_split(mel_spect, augmented_mel_spect, labels, test_size=0.2)

# Build augmented labels and train
aug_label_train = np.asarray(list(itertools.chain.from_iterable([[label] * nb_augmented for label in label_train])))
AUG_MEL_SPECT_train = np.asarray(list(itertools.chain.from_iterable(AUG_MEL_SPECT_train)))

# Concatenate original and augmented
X_train = np.concatenate((MEL_SPECT_train, AUG_MEL_SPECT_train))
y_train = np.concatenate((label_train, aug_label_train))

# Build test set
X_test = MEL_SPECT_test
y_test = label_test

# Delete
del MEL_SPECT_train, AUG_MEL_SPECT_train, label_train, aug_label_train, AUG_MEL_SPECT_test, MEL_SPECT_test, label_test
del mel_spect, augmented_mel_spect, labels

# %%
print(X_train.shape)
# Out:
# (3225, 128, 384)

# %%
# Time distributed parameters
win_ts = 128
hop_ts = 64

# Split spectrogram into frames
def frame(x, win_step=128, win_size=64):
    nb_frames = 1 + int((x.shape[2] - win_size) / win_step)
    frames = np.zeros((x.shape[0], nb_frames, x.shape[1], win_size)).astype(np.float32)
    for t in range(nb_frames):
        frames[:,t,:,:] = np.copy(x[:,:,(t * win_step):(t * win_step + win_size)]).astype(np.float32)
    return frames

# Frame for TimeDistributed model
X_train = frame(X_train, hop_ts, win_ts)
X_test = frame(X_test, hop_ts, win_ts)

# %%
# Save Train and test set
pickle.dump(X_train.astype(np.float16), open('/content/drive/MyDrive/Emotion_Recognition/SER/[RAVDESS][MEL_SPECT][X_train].p', 'wb'))
pickle.dump(y_train, open('/content/drive/MyDrive/Emotion_Recognition/SER/[RAVDESS][MEL_SPECT][y_train].p', 'wb'))
pickle.dump(X_test.astype(np.float16), open('/content/drive/MyDrive/Emotion_Recognition/SER/[RAVDESS][MEL_SPECT][X_test].p', 'wb'))
pickle.dump(y_test, open('/content/drive/MyDrive/Emotion_Recognition/SER/[RAVDESS][MEL_SPECT][y_test].p', 'wb'))

# %%
X_train = pickle.load(open('/content/drive/MyDrive/Emotion_Recognition/SER/[RAVDESS][MEL_SPECT][X_train].p', 'rb'))
y_train = pickle.load(open('/content/drive/MyDrive/Emotion_Recognition/SER/[RAVDESS][MEL_SPECT][y_train].p', 'rb'))
y_test = pickle.load(open('/content/drive/MyDrive/Emotion_Recognition/SER/[RAVDESS][MEL_SPECT][y_test].p', 'rb'))
X_test = pickle.load(open('/content/drive/MyDrive/Emotion_Recognition/SER/[RAVDESS][MEL_SPECT][X_test].p', 'rb'))

# %%
# Encode Label from categorical to numerical
lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(np.ravel(y_train)))
y_test = np_utils.to_categorical(lb.transform(np.ravel(y_test)))

# %%
# Reshape for convolution
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1] , X_train.shape[2], X_train.shape[3], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1] , X_test.shape[2], X_test.shape[3], 1)

# %%
print(X_train.shape)
# Out:
# (3225, 5, 128, 128, 1)

# %%
K.clear_session()

# Define two sets of inputs: MFCC and FBANK
input_y = Input(shape=X_train.shape[1:], name='Input_MELSPECT')

## First LFLB (local feature learning block)
y = TimeDistributed(Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_1_MELSPECT')(input_y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_1_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_1_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'), name='MaxPool_1_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_1_MELSPECT')(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_2_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_2_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_2_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_2_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_2_MELSPECT')(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_3_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_3_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_3_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_3_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_3_MELSPECT')(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_4_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_4_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_4_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_4_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_4_MELSPECT')(y)

## Flat
y = TimeDistributed(Flatten(), name='Flat_MELSPECT')(y)

# Apply 2 LSTM layer and one FC
y = LSTM(256, return_sequences=False, dropout=0.2, name='LSTM_1')(y)
y = Dense(y_train.shape[1], activation='softmax', name='FC')(y)

# Build final model
model = Model(inputs=input_y, outputs=y)

# %%
# Compile model
model.compile(optimizer=SGD(learning_rate=0.01, momentum=0.8), loss='categorical_crossentropy', metrics=['accuracy'])

# Save best model
best_model_save = ModelCheckpoint('drive/My Drive/Emotion_Recognition/SER/Model/[CNN-LSTM]Model.hdf5', save_best_only=True, monitor='val_accuracy', mode='max')

# Early stopping
early_stopping = EarlyStopping(monitor='val_accuracy', patience=30, verbose=1, mode='max')

# Fit model
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stopping, best_model_save])
# Out:
# Epoch 1/100
# 51/51 [==============================] - 43s 501ms/step - loss: 1.9439 - accuracy: 0.1724 - val_loss: 2.0634 - val_accuracy: 0.1375
# Epoch 2/100
# 51/51 [==============================] - 22s 434ms/step - loss: 1.8564 - accuracy: 0.2375 - val_loss: 1.9617 - val_accuracy: 0.1599
# Epoch 3/100
# 51/51 [==============================] - 22s 438ms/step - loss: 1.7427 - accuracy: 0.2967 - val_loss: 1.7660 - val_accuracy: 0.2974
# Epoch 4/100
# 51/51 [==============================] - 23s 442ms/step - loss: 1.6655 - accuracy: 0.3153 - val_loss: 1.6568 - val_accuracy: 0.3346
# Epoch 5/100
# 51/51 [==============================] - 22s 441ms/step - loss: 1.6313 - accuracy: 0.3414 - val_loss: 1.5813 - val_accuracy: 0.3755
# Epoch 6/100
# 51/51 [==============================] - 22s 434ms/step - loss: 1.5841 - accuracy: 0.3625 - val_loss: 1.5740 - val_accuracy: 0.3717
# Epoch 7/100
# 51/51 [==============================] - 23s 443ms/step - loss: 1.5452 - accuracy: 0.3873 - val_loss: 1.5079 - val_accuracy: 0.4647
# Epoch 8/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.5062 - accuracy: 0.4028 - val_loss: 1.4813 - val_accuracy: 0.4461
# Epoch 9/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.4993 - accuracy: 0.3972 - val_loss: 1.4447 - val_accuracy: 0.4610
# Epoch 10/100
# 51/51 [==============================] - 22s 441ms/step - loss: 1.4490 - accuracy: 0.4177 - val_loss: 1.4002 - val_accuracy: 0.4684
# Epoch 11/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.4321 - accuracy: 0.4350 - val_loss: 1.7328 - val_accuracy: 0.3717
# Epoch 12/100
# 51/51 [==============================] - 22s 438ms/step - loss: 1.3757 - accuracy: 0.4626 - val_loss: 1.5819 - val_accuracy: 0.4052
# Epoch 13/100
# 51/51 [==============================] - 22s 434ms/step - loss: 1.3717 - accuracy: 0.4453 - val_loss: 1.6064 - val_accuracy: 0.3978
# Epoch 14/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.3525 - accuracy: 0.4698 - val_loss: 2.0180 - val_accuracy: 0.3123
# Epoch 15/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.3235 - accuracy: 0.4847 - val_loss: 1.9989 - val_accuracy: 0.3011
# Epoch 16/100
# 51/51 [==============================] - 22s 434ms/step - loss: 1.3097 - accuracy: 0.4791 - val_loss: 1.4512 - val_accuracy: 0.4387
# Epoch 17/100
# 51/51 [==============================] - 22s 435ms/step - loss: 1.2829 - accuracy: 0.4958 - val_loss: 1.5880 - val_accuracy: 0.4164
# Epoch 18/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.2609 - accuracy: 0.5166 - val_loss: 1.7197 - val_accuracy: 0.3569
# Epoch 19/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.2467 - accuracy: 0.5216 - val_loss: 1.6545 - val_accuracy: 0.3978
# Epoch 20/100
# 51/51 [==============================] - 22s 436ms/step - loss: 1.2147 - accuracy: 0.5219 - val_loss: 1.5140 - val_accuracy: 0.4349
# Epoch 21/100
# 51/51 [==============================] - 22s 435ms/step - loss: 1.1811 - accuracy: 0.5482 - val_loss: 1.6494 - val_accuracy: 0.4275
# Epoch 22/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.1664 - accuracy: 0.5581 - val_loss: 1.8371 - val_accuracy: 0.3569
# Epoch 23/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.1569 - accuracy: 0.5553 - val_loss: 1.7019 - val_accuracy: 0.4238
# Epoch 24/100
# 51/51 [==============================] - 22s 440ms/step - loss: 1.0971 - accuracy: 0.5684 - val_loss: 1.2810 - val_accuracy: 0.4870
# Epoch 25/100
# 51/51 [==============================] - 23s 442ms/step - loss: 1.0757 - accuracy: 0.5864 - val_loss: 1.3490 - val_accuracy: 0.4944
# Epoch 26/100
# 51/51 [==============================] - 23s 444ms/step - loss: 1.0398 - accuracy: 0.5966 - val_loss: 1.2408 - val_accuracy: 0.5428
# Epoch 27/100
# 51/51 [==============================] - 22s 436ms/step - loss: 1.0386 - accuracy: 0.6062 - val_loss: 1.2828 - val_accuracy: 0.5204
# Epoch 28/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.0274 - accuracy: 0.6084 - val_loss: 1.3626 - val_accuracy: 0.4944
# Epoch 29/100
# 51/51 [==============================] - 22s 437ms/step - loss: 1.0097 - accuracy: 0.6124 - val_loss: 1.3288 - val_accuracy: 0.5130
# Epoch 30/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.9547 - accuracy: 0.6375 - val_loss: 1.6547 - val_accuracy: 0.4201
# Epoch 31/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.9449 - accuracy: 0.6369 - val_loss: 1.3746 - val_accuracy: 0.5390
# Epoch 32/100
# 51/51 [==============================] - 22s 440ms/step - loss: 0.9481 - accuracy: 0.6437 - val_loss: 1.1690 - val_accuracy: 0.5836
# Epoch 33/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.9125 - accuracy: 0.6474 - val_loss: 1.1535 - val_accuracy: 0.5651
# Epoch 34/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.9039 - accuracy: 0.6561 - val_loss: 1.2822 - val_accuracy: 0.5576
# Epoch 35/100
# 51/51 [==============================] - 22s 436ms/step - loss: 0.9014 - accuracy: 0.6574 - val_loss: 1.4212 - val_accuracy: 0.5316
# Epoch 36/100
# 51/51 [==============================] - 23s 443ms/step - loss: 0.8838 - accuracy: 0.6567 - val_loss: 1.1611 - val_accuracy: 0.5874
# Epoch 37/100
# 51/51 [==============================] - 24s 462ms/step - loss: 0.8407 - accuracy: 0.6803 - val_loss: 1.0995 - val_accuracy: 0.6022
# Epoch 38/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.8401 - accuracy: 0.6803 - val_loss: 1.3168 - val_accuracy: 0.5316
# Epoch 39/100
# 51/51 [==============================] - 22s 441ms/step - loss: 0.8123 - accuracy: 0.6943 - val_loss: 1.0525 - val_accuracy: 0.5985
# Epoch 40/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.8134 - accuracy: 0.6847 - val_loss: 1.6932 - val_accuracy: 0.4684
# Epoch 41/100
# 51/51 [==============================] - 22s 438ms/step - loss: 0.7966 - accuracy: 0.7029 - val_loss: 1.2633 - val_accuracy: 0.5725
# Epoch 42/100
# 51/51 [==============================] - 22s 436ms/step - loss: 0.8086 - accuracy: 0.6952 - val_loss: 1.0728 - val_accuracy: 0.5836
# Epoch 43/100
# 51/51 [==============================] - 22s 441ms/step - loss: 0.7797 - accuracy: 0.6989 - val_loss: 1.4925 - val_accuracy: 0.5576
# Epoch 44/100
# 51/51 [==============================] - 23s 445ms/step - loss: 0.7380 - accuracy: 0.7163 - val_loss: 1.0272 - val_accuracy: 0.6208
# Epoch 45/100
# 51/51 [==============================] - 23s 447ms/step - loss: 0.7409 - accuracy: 0.7113 - val_loss: 1.0912 - val_accuracy: 0.6245
# Epoch 46/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.7232 - accuracy: 0.7228 - val_loss: 2.0606 - val_accuracy: 0.4387
# Epoch 47/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.7153 - accuracy: 0.7250 - val_loss: 1.4378 - val_accuracy: 0.5465
# Epoch 48/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.6806 - accuracy: 0.7426 - val_loss: 1.2252 - val_accuracy: 0.5799
# Epoch 49/100
# 51/51 [==============================] - 22s 440ms/step - loss: 0.6752 - accuracy: 0.7439 - val_loss: 1.2140 - val_accuracy: 0.5836
# Epoch 50/100
# 51/51 [==============================] - 23s 447ms/step - loss: 0.6862 - accuracy: 0.7476 - val_loss: 1.0727 - val_accuracy: 0.6543
# Epoch 51/100
# 51/51 [==============================] - 22s 439ms/step - loss: 0.6732 - accuracy: 0.7433 - val_loss: 1.0805 - val_accuracy: 0.6245
# Epoch 52/100
# 51/51 [==============================] - 23s 443ms/step - loss: 0.6622 - accuracy: 0.7513 - val_loss: 0.9596 - val_accuracy: 0.6617
# Epoch 53/100
# 51/51 [==============================] - 22s 441ms/step - loss: 0.6486 - accuracy: 0.7575 - val_loss: 1.1308 - val_accuracy: 0.6245
# Epoch 54/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.6240 - accuracy: 0.7591 - val_loss: 1.1208 - val_accuracy: 0.6134
# Epoch 55/100
# 51/51 [==============================] - 22s 438ms/step - loss: 0.6192 - accuracy: 0.7603 - val_loss: 1.1573 - val_accuracy: 0.6059
# Epoch 56/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.6200 - accuracy: 0.7637 - val_loss: 1.1482 - val_accuracy: 0.6543
# Epoch 57/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.6039 - accuracy: 0.7771 - val_loss: 1.0422 - val_accuracy: 0.6468
# Epoch 58/100
# 51/51 [==============================] - 22s 438ms/step - loss: 0.5792 - accuracy: 0.7870 - val_loss: 1.0665 - val_accuracy: 0.6617
# Epoch 59/100
# 51/51 [==============================] - 22s 438ms/step - loss: 0.5873 - accuracy: 0.7764 - val_loss: 1.0804 - val_accuracy: 0.6431
# Epoch 60/100
# 51/51 [==============================] - 22s 436ms/step - loss: 0.5633 - accuracy: 0.7885 - val_loss: 1.3660 - val_accuracy: 0.5799
# Epoch 61/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.5473 - accuracy: 0.7919 - val_loss: 1.0989 - val_accuracy: 0.6431
# Epoch 62/100
# 51/51 [==============================] - 22s 436ms/step - loss: 0.5222 - accuracy: 0.8081 - val_loss: 1.4512 - val_accuracy: 0.5948
# Epoch 63/100
# 51/51 [==============================] - 22s 436ms/step - loss: 0.5272 - accuracy: 0.8093 - val_loss: 0.9920 - val_accuracy: 0.6580
# Epoch 64/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.5297 - accuracy: 0.8084 - val_loss: 2.2251 - val_accuracy: 0.4647
# Epoch 65/100
# 51/51 [==============================] - 22s 434ms/step - loss: 0.5181 - accuracy: 0.8102 - val_loss: 1.2955 - val_accuracy: 0.6394
# Epoch 66/100
# 51/51 [==============================] - 22s 440ms/step - loss: 0.5000 - accuracy: 0.8143 - val_loss: 0.9461 - val_accuracy: 0.6989
# Epoch 67/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.4879 - accuracy: 0.8205 - val_loss: 1.2739 - val_accuracy: 0.6208
# Epoch 68/100
# 51/51 [==============================] - 22s 434ms/step - loss: 0.4769 - accuracy: 0.8242 - val_loss: 0.9443 - val_accuracy: 0.6989
# Epoch 69/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.4770 - accuracy: 0.8226 - val_loss: 1.1314 - val_accuracy: 0.6617
# Epoch 70/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.4551 - accuracy: 0.8338 - val_loss: 1.0869 - val_accuracy: 0.6729
# Epoch 71/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.4341 - accuracy: 0.8412 - val_loss: 1.2437 - val_accuracy: 0.6357
# Epoch 72/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.4382 - accuracy: 0.8369 - val_loss: 1.2886 - val_accuracy: 0.6134
# Epoch 73/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.4193 - accuracy: 0.8546 - val_loss: 1.1674 - val_accuracy: 0.6729
# Epoch 74/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.4244 - accuracy: 0.8440 - val_loss: 1.5150 - val_accuracy: 0.6208
# Epoch 75/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.4289 - accuracy: 0.8384 - val_loss: 1.1336 - val_accuracy: 0.6506
# Epoch 76/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.4444 - accuracy: 0.8350 - val_loss: 1.1475 - val_accuracy: 0.6766
# Epoch 77/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.4084 - accuracy: 0.8509 - val_loss: 1.2971 - val_accuracy: 0.6468
# Epoch 78/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.3990 - accuracy: 0.8515 - val_loss: 1.1094 - val_accuracy: 0.6654
# Epoch 79/100
# 51/51 [==============================] - 22s 436ms/step - loss: 0.3653 - accuracy: 0.8664 - val_loss: 1.1775 - val_accuracy: 0.6766
# Epoch 80/100
# 51/51 [==============================] - 23s 444ms/step - loss: 0.3562 - accuracy: 0.8682 - val_loss: 0.8561 - val_accuracy: 0.7286
# Epoch 81/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.3741 - accuracy: 0.8608 - val_loss: 1.1381 - val_accuracy: 0.7026
# Epoch 82/100
# 51/51 [==============================] - 22s 434ms/step - loss: 0.3434 - accuracy: 0.8763 - val_loss: 1.6128 - val_accuracy: 0.5762
# Epoch 83/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.3441 - accuracy: 0.8713 - val_loss: 1.0578 - val_accuracy: 0.6617
# Epoch 84/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.3380 - accuracy: 0.8710 - val_loss: 1.2483 - val_accuracy: 0.6691
# Epoch 85/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.3189 - accuracy: 0.8871 - val_loss: 1.0009 - val_accuracy: 0.7286
# Epoch 86/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.3335 - accuracy: 0.8766 - val_loss: 1.2976 - val_accuracy: 0.6654
# Epoch 87/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.3131 - accuracy: 0.8825 - val_loss: 1.4959 - val_accuracy: 0.6097
# Epoch 88/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.3012 - accuracy: 0.8918 - val_loss: 1.3170 - val_accuracy: 0.6320
# Epoch 89/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.3275 - accuracy: 0.8766 - val_loss: 1.1018 - val_accuracy: 0.7286
# Epoch 90/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.2973 - accuracy: 0.8862 - val_loss: 1.2230 - val_accuracy: 0.6766
# Epoch 91/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.3126 - accuracy: 0.8794 - val_loss: 1.2355 - val_accuracy: 0.6691
# Epoch 92/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.2966 - accuracy: 0.8936 - val_loss: 1.2861 - val_accuracy: 0.6729
# Epoch 93/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.2676 - accuracy: 0.9076 - val_loss: 1.1174 - val_accuracy: 0.7026
# Epoch 94/100
# 51/51 [==============================] - 22s 436ms/step - loss: 0.2569 - accuracy: 0.9060 - val_loss: 1.1976 - val_accuracy: 0.6691
# Epoch 95/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.2683 - accuracy: 0.9026 - val_loss: 1.1001 - val_accuracy: 0.7212
# Epoch 96/100
# 51/51 [==============================] - 22s 435ms/step - loss: 0.2630 - accuracy: 0.9091 - val_loss: 1.4462 - val_accuracy: 0.6245
# Epoch 97/100
# 51/51 [==============================] - 23s 444ms/step - loss: 0.2501 - accuracy: 0.9095 - val_loss: 1.0446 - val_accuracy: 0.7472
# Epoch 98/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.2325 - accuracy: 0.9153 - val_loss: 1.3442 - val_accuracy: 0.6506
# Epoch 99/100
# 51/51 [==============================] - 22s 438ms/step - loss: 0.2380 - accuracy: 0.9157 - val_loss: 1.1603 - val_accuracy: 0.6617
# Epoch 100/100
# 51/51 [==============================] - 22s 437ms/step - loss: 0.2527 - accuracy: 0.9060 - val_loss: 1.3147 - val_accuracy: 0.6729

# %%
# Loss Curves
plt.figure(figsize=(25, 10))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'],'-g',linewidth=1.0)
plt.plot(history.history['val_loss'],'r',linewidth=1.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=14)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=22)

# Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'],'-g',linewidth=1.0)
plt.plot(history.history['val_accuracy'],'r',linewidth=1.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=14)
plt.xlabel('Epochs ',fontsize=16)

plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=22)
plt.show()

# %%
model.save('drive/My Drive/Emotion_Recognition/SER/savedmodel/[CNN-LSTM]M.h5')
model.save_weights('drive/My Drive/Emotion_Recognition/SER/savedmodel/[CNN-LSTM]W.h5')

# %%
#Prediction

from keras.models import load_model
model_ser = load_model('/content/drive/MyDrive/Emotion_Recognition/SER/savedmodel/[CNN-LSTM]M.h5')
model_ser.load_weights('/content/drive/MyDrive/Emotion_Recognition/SER/savedmodel/[CNN-LSTM]W.h5')
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
random_speech = '/content/drive/MyDrive/Emotion_Recognition/SER/test1.wav'

# Sample rate (16.0 kHz)
sample_rate = 16000

# Max pad lenght (3.0 sec)
max_pad_len = 49100

        # Read audio file
y, sr = librosa.core.load(random_speech, sr=sample_rate, offset=0.5)

        # Z-normalization
y = zscore(y)

        # Padding or truncated signal
if len(y) < max_pad_len:
  y_padded = np.zeros(max_pad_len)
  y_padded[:len(y)] = y
  y = y_padded
elif len(y) > max_pad_len:
  y = np.asarray(y[:max_pad_len])

# %%
# Data Preprocessing
mel_spect = np.asarray(mel_spectrogram(y))
mel_spect = np.reshape(mel_spect,(1,128,384))
input = frame(mel_spect, hop_ts, win_ts)
input = input.reshape(input.shape[0], input.shape[1] , input.shape[2], input.shape[3], 1)

# %%
#Defining labels
def get_label(argument):
    labels = {0:'Neutral', 1:'Happy', 2:'Sad', 3:'Anger', 4:'Fear' , 5:'Disgust', 6:'Surprise'}
    return(labels.get(argument, "Invalid emotion"))

# %%
for speech in input:
    res = model_ser.predict(input)
    result_num = np.argmax(res)
    print(result_num)
    print(get_label(result_num))
    print(res)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 0
# Neutral
# [[8.6528790e-01 1.3452394e-01 1.8387460e-05 1.3748732e-04 2.6097314e-07
#   2.2947488e-05 9.0876647e-06]]

# %%
random_signal = y
random_filename = random_speech

# Plot signal wave
plt.figure(figsize=(10,5))
plt.plot(np.arange(len(random_signal))/float(sample_rate), random_signal)
plt.xlim((np.arange(len(random_signal))/float(sample_rate))[0], (np.arange(len(random_signal))/float(sample_rate))[-1])
plt.xlabel('Time (s)', fontsize=16)
plt.ylabel('Amplitude (dB)', fontsize=16)
#plt.title("Signal wave of file '{}' with label {}".format(random_filename, random_label), fontsize=18)
plt.show()

# Play audio file
print("Audio file '{}':".format(random_filename))
Audio(random_signal, rate=sample_rate)
# Out:
# Audio file '/content/drive/MyDrive/Emotion_Recognition/SER/test1.wav':
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Prediction using Mp4 file

# !pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
from os import path
from pydub import AudioSegment

# files
src = "/content/dia0_utt1.mp4"
dst = "/content/drive/MyDrive/Emotion_Recognition/SER/test2.wav"

# convert mp4 to wav
sound = AudioSegment.from_file(src,format="mp4")
sound.export(dst, format="wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/Emotion_Recognition/SER/test2.wav'>
